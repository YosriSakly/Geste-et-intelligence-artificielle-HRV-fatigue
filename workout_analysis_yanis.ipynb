# %%
# %matplotlib notebook
# %config InlineBackend.print_figure_kwargs={'bbox_inches': None}
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('HeartRate.csv')
df[['creationDate','startDate','endDate']]=df[['creationDate','startDate','endDate']].apply(pd.to_datetime,errors='coerce',format='%Y-%m-%d %H:%M:%S.%f')
#df.plot(x='creationDate',y='value')
#plt.show()

# %%
df=df[['startDate','value']]
df.set_index('startDate',inplace=True)

# %% [markdown]
# ## Filter for only working out time

# %% [markdown]
# ## For Week days:

# %%
df.index=pd.to_datetime(df.index)
mask=(df.index.hour>6) & (df.index.hour<8)
df_week_days=df[mask]

# %% [markdown]
# ## For Week-ends:

# %%
mask=(df.index.hour>8) & (df.index.hour<10)
df_weekend=df[mask]
df_weekend
# Out:
#                      value
# startDate
# 2019-02-14 09:01:33   55.0
# 2019-02-14 09:03:02   52.0
# 2019-02-14 09:10:38   55.0
# 2019-02-14 09:13:37   55.0
# 2019-02-14 09:17:14   68.0
# 2019-02-14 09:26:49   50.0
# 2019-02-14 09:31:47   51.0
# 2019-02-14 09:33:42   54.0
# 2019-02-14 09:41:29   51.0
# 2019-02-14 09:46:09   50.0
# 2019-02-14 09:49:32   50.0
# 2019-02-14 09:53:14   51.0
# 2019-02-14 09:58:34   50.0
# 2019-02-15 09:03:31   63.0
# 2019-02-15 09:07:55   56.0
# 2019-02-15 09:14:55   60.0
# 2019-02-15 09:24:15   53.0
# 2019-02-15 09:31:44   58.0
# 2019-02-15 09:34:21   47.0
# 2019-02-15 09:39:52   49.0
# 2019-02-15 09:42:14   49.0
# 2019-02-15 09:49:36   52.0
# 2019-02-15 09:53:02   49.0
# 2019-02-15 09:59:45   50.0
# 2019-02-16 09:00:02   83.0
# 2019-02-16 09:00:07   82.0
# 2019-02-16 09:00:10   82.0
# 2019-02-16 09:00:16   80.0
# 2019-02-16 09:00:24   76.0
# 2019-02-16 09:00:27   74.0
# ...                    ...
# 2019-03-03 09:50:35   77.0
# 2019-03-03 09:50:44   81.0
# 2019-03-03 09:50:49   76.0
# 2019-03-03 09:50:52   75.0
# 2019-03-03 09:50:56   74.0
# 2019-03-03 09:51:01   74.0
# 2019-03-03 09:51:06   74.0
# 2019-03-03 09:51:10   74.0
# 2019-03-03 09:51:16   75.0
# 2019-03-03 09:51:20   73.0
# 2019-03-03 09:51:42  100.0
# 2019-03-04 09:00:29   51.0
# 2019-03-04 09:07:39   52.0
# 2019-03-04 09:11:52   47.0
# 2019-03-04 09:14:20   47.0
# 2019-03-04 09:19:43   48.0
# 2019-03-04 09:24:30   47.0
# 2019-03-04 09:31:25   48.0
# 2019-03-04 09:34:30   50.0
# 2019-03-04 09:41:02   54.0
# 2019-03-04 09:45:22   61.0
# 2019-03-04 09:49:22   52.0
# 2019-03-04 09:54:14   48.0
# 2019-03-05 09:02:07   55.0
# 2019-03-05 09:08:00   53.0
# 2019-03-05 09:11:56   51.0
# 2019-03-05 09:16:00   52.0
# 2019-03-05 09:16:05   58.0
# 2019-03-05 09:16:09   58.0
# 2019-03-05 09:16:16   59.0
#
# [2031 rows x 1 columns]

# %%
from datetime import date
#Problem with March 1,4 , Feb 19,21,22,25,28,23
#int(date.today().strftime('%d'))+1
for i in [3,13,14,15,16,17,18,20,23,26,27,]:
    try:
        plt.figure()
        if i in [13,14,15,18,19,20,27,]:
            df_plot = df_week_days[df_week_days.index.day==i]
            #print (df_plot)
        else:
            if i in [16,17,26,3]:
                df_plot = df_weekend[df_weekend.index.day==i] 
        plt.plot(df_plot.index,df_plot.value)
        plt.gcf().autofmt_xdate()
    except:
        print('here')
        pass
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
