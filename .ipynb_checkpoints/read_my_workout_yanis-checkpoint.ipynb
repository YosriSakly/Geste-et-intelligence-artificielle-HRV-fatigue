# %%
# %run -i 'apple-health-data-parser' 'export.xml'
# Out:
# Reading data from export.xml . . . done
# apple-health-data-parser.py:130: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#   self.nodes = self.root.getchildren()
# Unexpected node of type ExportDate.
#
# Tags:
# ActivitySummary: 11
# ExportDate: 1
# Me: 1
# Record: 121673
# Workout: 5
#
# Fields:
# HKCharacteristicTypeIdentifierBiologicalSex: 1
# HKCharacteristicTypeIdentifierBloodType: 1
# HKCharacteristicTypeIdentifierDateOfBirth: 1
# HKCharacteristicTypeIdentifierFitzpatrickSkinType: 1
# activeEnergyBurned: 11
# activeEnergyBurnedGoal: 11
# activeEnergyBurnedUnit: 11
# appleExerciseTime: 11
# appleExerciseTimeGoal: 11
# appleStandHours: 11
# appleStandHoursGoal: 11
# creationDate: 121678
# dateComponents: 11
# device: 121669
# duration: 5
# durationUnit: 5
# endDate: 121678
# sourceName: 121678
# sourceVersion: 121678
# startDate: 121678
# totalDistance: 5
# totalDistanceUnit: 5
# totalEnergyBurned: 5
# totalEnergyBurnedUnit: 5
# type: 121673
# unit: 121673
# value: 121674
# workoutActivityType: 5
#
# Record types:
# ActiveEnergyBurned: 11226
# AppleExerciseTime: 423
# BasalEnergyBurned: 10596
# BodyMass: 1
# DistanceWalkingRunning: 44472
# FlightsClimbed: 7713
# HeartRate: 4107
# HeartRateVariabilitySDNN: 2
# Height: 1
# RestingHeartRate: 5
# StepCount: 43125
# WalkingHeartRateAverage: 2
#
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/BasalEnergyBurned.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/HeartRate.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/BodyMass.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/DistanceWalkingRunning.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/RestingHeartRate.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/StepCount.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/Height.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/AppleExerciseTime.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/HeartRateVariabilitySDNN.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/WalkingHeartRateAverage.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/ActiveEnergyBurned.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/FlightsClimbed.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/Workout.csv for writing
# Opening /Users/yanis/Documents/GitHub/Geste-et-intelligence-artificielle-HRV-fatigue/ActivitySummary.csv for writing
# Written BasalEnergyBurned data.
# Written HeartRate data.
# Written BodyMass data.
# Written DistanceWalkingRunning data.
# Written ActivitySummary data.
# Written WalkingHeartRateAverage data.
# Written StepCount data.
# Written Height data.
# Written AppleExerciseTime data.
# Written HeartRateVariabilitySDNN data.
# Written Workout data.
# Written FlightsClimbed data.
# Written RestingHeartRate data.
# Written ActiveEnergyBurned data.

# %%
# %matplotlib notebook
# %config InlineBackend.print_figure_kwargs={'bbox_inches': None}
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv('HeartRate.csv')
df[['creationDate','startDate','endDate']]=df[['creationDate','startDate','endDate']].apply(pd.to_datetime,errors='coerce',format='%Y-%m-%d %H:%M:%S.%f')
#df.plot(x='creationDate',y='value')
#plt.show()

# %%
df=df[['startDate','value']]
df.set_index('startDate',inplace=True)

# %% [markdown]
# ## Filter for only working out time

# %% [markdown]
# ## For Week days:

# %%
df.index=pd.to_datetime(df.index)
mask=(df.index.hour>6) & (df.index.hour<8)
df_week_days=df[mask]

# %% [markdown]
# ## For Week-ends:

# %%
mask=(df.index.hour>8) & (df.index.hour<10)
df_weekend=df[mask]

# %%
from datetime import date
#int(date.today().strftime('%d'))+1
for i in range (13,df.index[-1].day):
    try:
        plt.figure()
        df_plot=df_week_days[df_week_days.index.day==i] if i not in [2,3,9,10,16,17,23,24] else df_weekend[df_weekend.index.day==i]
        plt.plot(df_plot.index,df_plot.value)
        plt.gcf().autofmt_xdate()
    except:
        pass
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
def filter_signal(df,column,plotBoth=True):
    from scipy import fftpack
    import numpy as np
    
    time_vec=df.index.values
    sig = df[column].values
    sig_fft = fftpack.fft(sig)
    power = np.abs(sig_fft)
    sample_freq = fftpack.fftfreq(sig.size, d=1)
    pos_mask = np.where(sample_freq > 0)
    freqs = sample_freq[pos_mask]
    peak_freq = freqs[power[pos_mask].argmax()]
    high_freq_fft = sig_fft.copy()
    high_freq_fft[np.abs(sample_freq) > peak_freq] = 0
    filtered_sig = fftpack.ifft(high_freq_fft)
    if plotBoth:
        plt.figure(figsize=(6, 5))
        plt.plot(time_vec, sig, label='Original signal')
        plt.plot(time_vec, filtered_sig, linewidth=3, label='Filtered signal')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.legend(loc='best')

# %%
for i in range
df_bis=df_week_days[df_week_days.index.day==13]
filter_signal(df=df_bis,column='value')
# Out:
# <img src="data:image/png;base64,..." width="600">
