# %% [markdown]
# # Project HRV fatigue

# %%
###########################
### package importation ###
###########################

import glob
import wfdb
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import detrend, butter, lfilter, freqz, hilbert, find_peaks, find_peaks_cwt
from statsmodels.tsa.stattools import ccf
import seaborn as sns
from scipy import fftpack
from sklearn.cluster import KMeans
import scipy.spatial.distance as ssd 
import scipy.stats as ss

sns.set_style("darkgrid") # style for the plots

# %% [markdown]
# # Function definition
#
# Here we will define some functions that we will use later.

# %%
def read(file):
    '''
    Read a .hea file and convert it to a dataframe
    '''
    
    w = wfdb.rdsamp(file) # using the builtin function of PhysioNet package 'wfdb'
    return(pd.DataFrame(data=w[0][:, :2], columns={'ECG', 'PPG'})) # saving data as a DataFrame (sea Pandas)

# %%
def creating_dataframe(file):
    '''
    Creating a DataFrame (sea Pandas) with the data from the .hea file. We also add 'detrend' data.
    '''
    
    ##########################
    ### creating DataFrame ###
    ##########################
    
    print("Reading and saving as dataframe: " + file + "\n")
    df_temp = read(file) # acces data from .hea file
    df_temp = df_temp.dropna() # drop Na
    
    ############################
    ### adding no trend data ###
    ############################
    
    print("Adding no trend data\n")
    for col in {'ECG', 'PPG'}: # creating 'no trend' data
        temp = df_temp[col] - df_temp[col].mean() # removing the mean 
        df_temp[col + '_no_trend'] = detrend(temp.values) # removing linear trend
    
    return(df_temp)

# %%
def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# %%
def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return y

# %%
def add_butter_filter(df, lowcut, highcut, fs):
    '''
    Add butter filter
    '''
   
    ############################
    ### adding butter filter ###
    ############################
    
    print("Adding butter filter with lowcut of " + str(lowcut) + " Hz" + " and highcut of " + str(highcut) + " Hz\n")
    for col in {'ECG', 'PPG'}: # butter on no trend data !
        df[col + '_butter_' + str(lowcut) + '_' + str(highcut)] = butter_bandpass_filter(
                                                                  df[col + '_no_trend'].values, lowcut, highcut,
                                                                  fs, order=3)
    return(df)

# %%
def add_hilbert(df):
    '''
    Add Hilbert transform, see: https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.hilbert.html.
    '''
   
    ################################
    ### adding Hilbert transform ###
    ################################
    
    print("Add Hilbert transform")
    for col in {'ECG', 'PPG'}: # Hilbert on no trend data !
        temp = hilbert(df[col + '_no_trend'].values)
        df[col + '_hilbert_envelope'] = np.abs(temp)
        df[col + '_hilbert_phase'] = np.unwrap(np.angle(temp))
        temp_2 = list((np.diff(df[col + '_hilbert_phase'].values) / (2.0 * np.pi) * frequency_sampling))
        temp_2.append(0)
        df[col + '_hilbert_frequency'] = temp_2
    return(df)

# %%
def plot_fourier(data, windows_freq_min=None, windows_freq_max=None, log_scale=False):
    '''
    Plot the Fourier transform of data. Windows threshold must be given in Hz.
    '''
    
    #########################
    ### Fourier transform ###
    #########################

    data_fourier = fftpack.fft(data)
    freqs = fftpack.fftfreq(len(data)) * frequency_sampling
    df_temp = pd.DataFrame(data={'freqs': freqs, 'abs(fourier)': np.abs(data_fourier)})
    plt.figure(figsize=(15, 7))
    if windows_freq_min != None and windows_freq_min != None:
        df_temp = df_temp[(windows_freq_min <= df_temp.freqs) & (df_temp.freqs <= windows_freq_max)]
        if log_scale:
            plt.xlim(np.log(windows_freq_min), np.log(windows_freq_max))
        else:
            plt.xlim(windows_freq_min, windows_freq_max)
    elif windows_freq_min != None:
        df_temp = df_temp[windows_freq_min <= df_temp.freqs]
        if log_scale:
            plt.xlim(left=np.log(windows_freq_min))
        else:
            plt.xlim(left=windows_freq_min) 
    elif windows_freq_max != None:
        df_temp = df_temp[df_temp.freqs <= windows_freq_max]
        if log_scale:
            plt.xlim(right=np.log(windows_freq_max))
        else:
            plt.xlim(right=windows_freq_max)   
    if log_scale:
        plt.plot(np.log(df_temp.freqs), np.log(df_temp['abs(fourier)']))
    else:
        plt.plot(df_temp.freqs, df_temp['abs(fourier)']) 
    plt.title('Fourier transform of ' + data.name)
    plt.xlabel('Frequency in Hertz [Hz]')
    plt.ylabel('Frequency Domain (Spectrum) Magnitude')
    plt.show()

# %%
def plot_cross_correlation(data_1, data_2, windows_low_x=None, windows_high_x=None):
    '''
    Plot cross-correlation of 2 time series.
    '''
    
    #########################
    ### cross correlation ###
    #########################
    
    time = np.linspace(0, np.shape(data_1)[0] / frequency_sampling, np.shape(data_1)[0])
    plt.figure(figsize=(15, 7))
    plt.plot(time, ccf(data_1, data_2))
    plt.title("Cross-correlation of " + data_1.name + " and " + data_2.name)
    if windows_low_x != None and windows_high_x != None:
        plt.xlim(windows_low_x, windows_high_x)
    elif windows_low_x != None:
        plt.xlim(left=windows_low_x)
    elif windows_high_x != None:
        plt.xlim(right=windows_high_x)
    plt.xlabel("time in second [s]")
    plt.ylabel("correlation")
    plt.show()

# %%
def plot_correlation_map(df):
    '''
    Plot correlation map.
    '''
    
    #######################
    ### correlation map ###
    #######################
    
    corr = df.corr()
    return(corr.style.background_gradient(cmap='coolwarm').set_precision(2))

# %%
def plot_dataframe(df, windows_low_x, windows_high_x, windows_low_y, windows_high_y, mask='all'):
    '''
    Plot a dataframe. You can provide a mask with a list, for instance: mask = ['PPG', 'ECG'].
    '''
    
    ######################
    ### DataFrame plot ###
    ######################
    
    time = np.linspace(0, np.shape(df.PPG.values)[0] / frequency_sampling, np.shape(df.PPG.values)[0])
    plt.figure(figsize=(15, 7))
    if mask=='all':
        for col in df.columns:
            plt.plot(time, df[col], label=col)
    else:
        for col in mask:
            plt.plot(time, df[col], label=col)
    plt.legend()
    plt.xlabel("time in second [s]")
    plt.ylabel("energy [mV]")
    plt.xlim([windows_low_x, windows_high_x])
    plt.ylim([windows_low_y, windows_high_y])
    plt.title('Mutiple plot')
    plt.show()

# %%
def plot_peak(data, windows_low_x=None, windows_high_x=None, distance=None):
    '''
    Finding peaks with scipy package
    '''
    
    #####################
    ### finding peaks ###
    #####################
    
    peaks, properties = find_peaks(data, distance=distance)
    plt.figure(figsize=(18, 7))
    time = np.linspace(0, np.shape(data)[0] / frequency_sampling, np.shape(data)[0])
    plt.plot(time, data)
    plt.plot(time[peaks], data[peaks], "o")
    if windows_low_x != None and windows_high_x != None:
        plt.xlim(windows_low_x, windows_high_x)
    elif windows_low_x != None:
        plt.xlim(left=windows_low_x)
    elif windows_high_x != None:
        plt.xlim(right=windows_high_x)
    plt.title("Finding peaks of " + data.name)
    plt.xlabel('time in second [s]')
    plt.ylabel('energy [mV]')
    plt.show()
    
        
    ########################################
    ### computing distance between peaks ###
    ########################################
    
    distance = peaks[1:] - peaks[:-1] 
    distance_cluster = pd.DataFrame(distance)
    
    #######################
    ### Cluster K-means ###
    #######################
    
    model = KMeans(n_clusters=3) # create the model
    model.fit(distance_cluster) # fit the model with our data
    colormap = np.array(['Red','green','blue'])
    
    ################
    ### Plotting ###
    ################

    plt.figure(figsize=(15, 7))
    plt.scatter(np.arange(len(distance_cluster)) / frequency_sampling,
                distance_cluster / frequency_sampling, c=colormap[model.labels_])
    plt.title("Distance between peaks of " + data.name + ' (clustered using Kmeans method)')
    plt.xlabel('peaks indices')
    plt.ylabel('distance in second [s]')
    plt.show()
    
    plt.figure(figsize=(15, 7))
    plt.hist(distance / frequency_sampling , bins=200)
    plt.title("Distribution of the distance between peaks of " + data.name)
    plt.xlabel('distance in second [s]')
    plt.ylabel('frequency')
    plt.show()
    return peaks, distance

# %%
def plot_peak_corr(peaks_1, peaks_2):
    '''
    plotting peaks of one signal with respect to the ones of another signal
    '''
    
    max_indice = min(len(peaks_1), len(peaks_2))
    peaks_1_temp = peaks_1[:max_indice]
    peaks_2_temp = peaks_2[:max_indice]
    
    ################
    ### Plotting ###
    ################
    
    plt.figure(figsize=(15, 7))
    plt.plot(peaks_1_temp / frequency_sampling, peaks_2_temp / frequency_sampling)
    plt.plot(peaks_1_temp / frequency_sampling, peaks_1_temp / frequency_sampling)
    plt.title('Distances correlation between the two signals')
    plt.xlabel('peaks times for signal 1 in second [s]')
    plt.ylabel('peaks times for signal 2 in second [s]')
    plt.show()
    
    print('distance measure based on correlation between the two vectors: ',
          ssd.correlation(peaks_1_temp, peaks_2_temp) )# Computes a distance measure based on correlation between the two vectors
    print ('correlation matrix: \n',
           np.corrcoef(peaks_1_temp, peaks_2_temp)) # Gives back the correlation matrix for the two arrays
    print ('spearman correlation: ', 
           ss.spearmanr(peaks_1_temp, peaks_2_temp)) # Gives the spearman correlation for the two arrays

# %% [markdown]
# # Data processing
#
# In this part we prepare the data from [Physionet](https://physionet.org/) to be used during this project. All data have the same frequency sampling: **256**.

# %%
print("All the files available:\n")
hea_file = []
for file in glob.glob("Data/*.hea"): # print all file in the 'Data' folder with .hea as extension
    hea_file.append(file[:-4]) # list of all files, can be used in the 'read' function
    print(file[5:-4])
# Out:
# All the files available:
#
# s1_high_resistance_bike
# s1_low_resistance_bike
# s1_walk
# s2_high_resistance_bike
# s2_low_resistance_bike
# s2_walk
# s3_high_resistance_bike
# s3_low_resistance_bike
# s3_run
# s3_walk
# s4_run
# s5_low_resistance_bike
# s5_run
# s6_low_resistance_bike
# s6_run
# s6_walk
# s8_run
# s8_walk
# s9_walk

# %% [markdown]
# All files' names has been saved in a list: **hea_file**.

# %%
frequency_sampling = 256 # set the frequency variable
df = creating_dataframe(hea_file[7]) # creat a dataframe from hea_list
df = add_butter_filter(df, 0.66, 3.75, frequency_sampling) # add butter filter with ECG_no_trend, PPG_no_trend
df = add_hilbert(df) # add Hilbert transform with ECG_no_trend, PPG_no_trend
print("\nFinal DataFrame:")
df.head(5) # display the first 5 elements
# Out:
# Reading and saving as dataframe: Data\s3_low_resistance_bike
#
# Adding no trend data
#
# Adding butter filter with lowcut of 0.66 Hz and highcut of 3.75 Hz
#
# Add Hilbert transform
#
# Final DataFrame:
#           ECG         PPG  ECG_no_trend  PPG_no_trend  ECG_butter_0.66_3.75  \
# 0  181.818182  694.546344    181.959852   -704.008777              0.009210
# 1  172.389473  685.640032    172.531120   -712.915013              0.062556
# 2  186.718141  677.573249    186.859766   -720.981719              0.216291
# 3  178.625784  671.003019    178.767387   -727.551872              0.526719
# 4  113.886930  666.440359    114.028510   -732.114455              1.036891
#
#    PPG_butter_0.66_3.75  ECG_hilbert_envelope  ECG_hilbert_phase  \
# 0             -0.035634            450.900427          -1.155405
# 1             -0.244329            335.730275          -1.031074
# 2             -0.850162            339.831561          -0.988600
# 3             -2.077983            263.935763          -0.826691
# 4             -4.113897            209.256890          -0.994501
#
#    ECG_hilbert_frequency  PPG_hilbert_envelope  PPG_hilbert_phase  \
# 0               5.065722           1170.291025           2.216258
# 1               1.730546            860.910416           2.546496
# 2               6.596763            859.889769           2.565244
# 3              -6.837210            788.429338           2.746047
# 4             -14.358182            785.245145           2.771624
#
#    PPG_hilbert_frequency
# 0              13.455107
# 1               0.763879
# 2               7.366556
# 3               1.042111
# 4               5.625754

# %% [markdown]
# After the DataFrame is created, one can simply add information in it by playing with the DataFrame and the functions as above.

# %% [markdown]
# # Results

# %% [markdown]
# ### Fourier transform

# %%
plot_fourier(df.ECG, windows_freq_min=0.01, windows_freq_max=10, log_scale=False)

# %% [markdown]
# ### Multiple plot

# %%
mask = ['ECG', 'PPG', 'PPG_butter_0.66_3.75', 'PPG_hilbert_envelope']
plot_dataframe(df, windows_low_x=10, windows_high_x=20, windows_low_y=None, windows_high_y=None, mask=mask)

# %% [markdown]
# ### Cross-correlation of 2 time series

# %%
plot_cross_correlation(df.ECG, df.PPG)

# %% [markdown]
# ### Correlation map

# %%
plot_correlation_map(df)
# Out:
# <style  type="text/css" >
#     #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col0 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col1 {
#             background-color:  #6384eb;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col2 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col3 {
#             background-color:  #6485ec;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col4 {
#             background-color:  #4257c9;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col5 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col6 {
#             background-color:  #6a8bef;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col7 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col8 {
#             background-color:  #7295f4;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col9 {
#             background-color:  #a9c6fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col10 {
#             background-color:  #abc8fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow0_col11 {
#             background-color:  #3b4cc0;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col0 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col1 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col2 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col3 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col4 {
#             background-color:  #3b4cc0;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col5 {
#             background-color:  #cfdaea;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col6 {
#             background-color:  #6b8df0;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col7 {
#             background-color:  #a7c5fe;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col8 {
#             background-color:  #779af7;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col9 {
#             background-color:  #92b4fe;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col10 {
#             background-color:  #a9c6fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow1_col11 {
#             background-color:  #445acc;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col0 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col1 {
#             background-color:  #6384eb;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col2 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col3 {
#             background-color:  #6485ec;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col4 {
#             background-color:  #4257c9;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col5 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col6 {
#             background-color:  #6a8bef;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col7 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col8 {
#             background-color:  #7295f4;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col9 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col10 {
#             background-color:  #abc8fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow2_col11 {
#             background-color:  #3b4cc0;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col0 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col1 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col2 {
#             background-color:  #4b64d5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col3 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col4 {
#             background-color:  #3b4cc0;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col5 {
#             background-color:  #cfdaea;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col6 {
#             background-color:  #6c8ff1;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col7 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col8 {
#             background-color:  #779af7;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col9 {
#             background-color:  #90b2fe;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col10 {
#             background-color:  #abc8fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow3_col11 {
#             background-color:  #445acc;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col0 {
#             background-color:  #3c4ec2;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col1 {
#             background-color:  #4c66d6;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col2 {
#             background-color:  #3c4ec2;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col3 {
#             background-color:  #4e68d8;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col4 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col5 {
#             background-color:  #4c66d6;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col6 {
#             background-color:  #7295f4;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col7 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col8 {
#             background-color:  #688aef;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col9 {
#             background-color:  #aec9fc;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col10 {
#             background-color:  #abc8fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow4_col11 {
#             background-color:  #3e51c5;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col0 {
#             background-color:  #506bda;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col1 {
#             background-color:  #dedcdb;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col2 {
#             background-color:  #516ddb;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col3 {
#             background-color:  #dedcdb;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col4 {
#             background-color:  #5875e1;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col5 {
#             background-color:  #b40426;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col6 {
#             background-color:  #7093f3;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col7 {
#             background-color:  #aac7fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col8 {
#             background-color:  #7b9ff9;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col9 {
#             background-color:  #bad0f8;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col10 {
#             background-color:  #abc8fd;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow5_col11 {
#             background-color:  #3f53c6;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow6_col0 {
#             background-color:  #4257c9;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow6_col1 {
#             background-color:  #5a78e4;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow6_col2 {
#             background-color:  #4055c8;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow6_col3 {
#             background-color:  #5d7ce6;
#         }    #T_0a8c2840_40ca_11e9_860f_409f38455e9crow6_col4 {

# %% [markdown]
# ### Peaks detection
#
# According to [American Heart Association](https://www.heart.org/en/) we have those repartition:
#
# * 40-60 bpm average for well-trained athletes, no exercise (lower than the average people).
# * ~225 bpm as maximum.
#
# For simplicity we will set the limits of 60-225 bpm which is equivalent to:
#
# $$ T_{\min} = \frac{60}{60} = 1 \text{ s} \Longrightarrow f_{\min} = \frac{1}{T} = 1 \text{ Hz}$$
# $$ T_{\max} = \frac{60}{225} = \frac{4}{15} \sim 0.26 \text{ s} \Longrightarrow f_{\max} = \frac{1}{T} = 3.75 \text{ Hz}$$
#
# Therefore we have the theoretical minimal and maximal distance of the heart beat rate. In our case we know that for all the data the frequency sampling is set to 256.
#
# $$ \text{distance}_{\max} = T_{\min} \times 256 = 256 $$
# $$ \text{distance}_{\min} = T_{\max} \times 256 \sim 68.26 \Longrightarrow 68$$
#
# We also have the average value: $\text{distance}_{\text{mean}} = 162$. Mind that these are not magic values that will work with all datasets (only here to give a hint).

# %%
peaks_ECG, distance_ECG = plot_peak(df.ECG, windows_low_x=100, windows_high_x=115, distance=100)

# %%
peaks_PPG,distance_PPG = plot_peak(df.PPG, windows_low_x=100, windows_high_x=115, distance=100)

# %%
plot_peak_corr(peaks_ECG,peaks_PPG)
# Out:
# distance measure based on correlation between the two vectors:  0.0002980572180280028
# correlation matrix:
#  [[1.         0.99970194]
#  [0.99970194 1.        ]]
# spearman correlation:  SpearmanrResult(correlation=1.0, pvalue=0.0)
